# %%
# !pip install simworker celery redis
import tellurium as te
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# Requirement already satisfied (use --upgrade to upgrade): simworker in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): celery in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): redis in /home/user/.virtualenvs/localpy/lib/python2.7/site-packages
# Cleaning up...

# %%
model = '''
  #Reactions:
  J0:    -> S1;  J0_v0
  J1: S1 ->   ;  J1_k3*S1
  J2: S1 -> S2; (J2_k1*S1)*(1 + J2_c*S2^J2_q)
  J3: S2 ->   ;  J3_k2*S2

  # Species initializations:
  S1 = 0
  S2 = 1

  # Variable initializations:
  J0_v0 = 8
  J1_k3 = 1
  J2_k1 = 1
  J2_c  = 1
  J2_q  = 3
  J3_k2 = 5
'''

rr = te.loadAntimonyModel(model)
print rr.model.getGlobalParameterValues()

TIME_START = 0
TIME_END = 5
TIME_STEPS = 80

data = rr.simulate(TIME_START, TIME_END, TIME_STEPS)
c = np.copy(data) # need to copy results or else it gets changed later
te.plotArray(data)
# Out:
# [ 8.  1.  1.  1.  3.  5.]
# <module 'matplotlib.pyplot' from '/usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc'>

# %%
def makeNoise(results, mean=0, std=1):
    import numpy as np
    dim = results.shape
    numSpecies = dim[1] - 1
    numPoints = dim[0]
    noise = np.hstack([np.array([np.random.normal(mean, std, numPoints)]).T for s in range(numSpecies)])
    return noise

noise = makeNoise(c, std=0.2)
noisyResults = np.hstack((np.array([c[:, 0]]).T, c[:, 1:] + noise))

# %%
def getSim(rr, params):
    rr.reset()
    rr.model.setGlobalParameterValues(params)
    return rr.simulate(TIME_START, TIME_END, TIME_STEPS)

def getFitness(obs):
    expected = noisyResults

    sumofsquares = 0
    for index, value in np.ndenumerate(obs):
            expectedValue = expected[index[0], index[1]]
            residual = (value - expectedValue)
            sumofsquares += residual ** 2

    return sumofsquares

# %%
MAX_GENS = 30
POPULATION = 40

# %%
import diffevolution
de = diffevolution.DiffEvolution(rr,
                   fitnessFcn=getFitness,
                   simFcn=getSim,
                   MAX_GENS=MAX_GENS,
                   POPULATION=POPULATION,
                   SAVE_RESULTS=True,
                   paramRangeDict={
                     'J0_v0': (8, 8),
                     'J1_k3': (1, 1),
                     'J2_k1': (1, 1),
                     #'J2_c': (1, 1),
                     #'J2_q': (3, 3),
                     #'J3_k2': (5, 5)
                   })
de.start()
de.plotFitnesses()
de.plotBest(observed=noisyResults)
# Out:
# 939.061303291
# 245.088059098
# inf
# 251.801824077
# 126.152546189
# 284.562397432
# 209.187204459
# 222.386232402
# 4094.79385886
# 540.037439549
# 190.635741477
# 216.458824482
# 208.89383261
# 284.204996147
# 104.997526807
# 590.771140037
# 244.352219133
# 265.192556025
# inf
# inf
# inf
# 327.567984658
# 521.337748826
# 1860.69806163
# 232.931590355
# 282.73904379
# 224.468764163
# 272.041350062
# 260.633052889
# 209.057643375
# 11432.7416016
# inf
# 59.6777507011
# 138.801868944
# 483.982292557
# inf
# inf
# 686.011050947
# 151.676674773
# 203.072009206
# Finished after 6.99637699127 seconds
# with population of 40 and 30 generations
# Best fitness value of 28.6948519036
# Best parameters of [8.0, 1.0, 1.0, 1.3020205068435906, 3.036947158069113, 5.4434705860009664]

# %%
def plotCorrelations(
    pInds, members
):
    import matplotlib.pyplot as mplot
    import numpy as np

    f, axarr = mplot.subplots(
        len(pInds),
        len(pInds),
        sharex='col',
        sharey='row')

    for i, p1 in enumerate(pInds):
        for j, p2 in enumerate(pInds):
            k1 = np.array([m.params[p1] for m in members])
            k2 = np.array([m.params[p2] for m in members])

            axarr[i, j].scatter(
                k1,
                k2)

            if (i == len(pInds) - 1):
                axarr[i, j].set_xlabel('%d' % (p2))
            if (j is 0):
                axarr[i, j].set_ylabel('%d' % (p1))

# %%
fitnesses = []
members = []
for g in de.generations:
    for f, m in zip(g['fitness'], g['members']):
        if f < 40:
            fitnesses.append(f)
            members.append(m)

pInds = [3, 4, 5]
import matplotlib.pyplot as mplot

plotCorrelations(pInds, members)

# %%
sbml = rr.getSBML()
expected = noisyResults
def asyncSim(rr, params):
    import tasks
    
    return tasks.rrChain.delay([
        ['load', sbml],
        ['reset'],
        [['model', 'setGlobalParameterValues'], params],
        ['simulate', TIME_START, TIME_END, TIME_STEPS]
    ])

def getAsyncFitness(obs):
    sumofsquares = 0
    for index, value in np.ndenumerate(obs):
        expectedValue = expected[index[0], index[1]]
        residual = (value - expectedValue)
        sumofsquares += residual ** 2
    return sumofsquares

# %%
import diffevolution
reload(diffevolution)
deAsync = diffevolution.DiffEvolution(rr,
                   fitnessFcn=getAsyncFitness,
                   simFcn=asyncSim,
                   ASYNC=True,
                   SAVE_RESULTS=True,
                   MAX_GENS=MAX_GENS,
                   POPULATION=POPULATION,
                   paramRangeDict={
                     'J0_v0': (8, 8),
                     'J1_k3': (1, 1),
                     'J2_k1': (1, 1),
                     #'J2_c': (1, 1),
                     #'J2_q': (3, 3),
                     #'J3_k2': (5, 5)
                   })
deAsync.start()
deAsync.plotFitnesses()
deAsync.plotBest(observed=noisyResults)
# Out:
# Finished after 16.0291810036 seconds
# with population of 40 and 20 generations
# Best fitness value of 43.6649633669
# Best parameters of [8.0, 1.0, 1.0, 1.4651034928349942, 2.333234702664818, 5.24410115549523]

# %%
import diffevolution
reload(diffevolution)
deAsync = diffevolution.DiffEvolution(rr,
                   fitnessFcn=getAsyncFitness,
                   simFcn=asyncSim,
                   ASYNC=True,
                   MAX_GENS=MAX_GENS,
                   POPULATION=POPULATION,
                   paramRangeDict={
                     'J0_v0': (8, 8),
                     'J1_k3': (1, 1),
                     'J2_k1': (1, 1),
                     'J2_c': (1, 1),
                     'J2_q': (3, 3),
                     #'J3_k2': (5, 5)
                   })
deAsync.start()
deAsync.plotFitnesses()
deAsync.plotBest(observed=noisyResults)

# %%
import tasks

# %%
import time
start = time.time()
tasks.add.delay(2, 2).get()
end = time.time()
print '%s seconds' % str(end-start)

# %%
import time
start = time.time()
numTrials = 1
asyncQueue = []
for i in range(numTrials):
    asyncQueue.append(tasks.add.delay(2, 2))
for job in asyncQueue:
    print job.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds per job' % str((end-start)/ numTrials)

# %%
from celery import group
import time
start = time.time()
numTrials = 30
asyncQueue = []
for i in range(numTrials):
    asyncQueue.append(tasks.add.s(2, 2))

result = group(asyncQueue).apply_async()
print result.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds per job' % str((end-start)/ numTrials)

# %%
import time
start = time.time()
asyncQueue = []
numSims = 300
for i in range(numSims):
    asyncQueue.append(tasks.rrChain.delay([['load', sbml], ['reset'], ['simulate', 0, 100, 100]]))
for job in asyncQueue:
    job.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/numSims)

# %%
from celery import group
import time
start = time.time()
#tasks.add.delay(2, 2).get()
asyncQueue = []
numSims = 300
for i in range(numSims):
    asyncQueue.append(tasks.rrChain.s([['load', sbml], ['reset'], ['simulate', 0, 100, 100]]))
result = group(asyncQueue).apply_async()
result.get()
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/numSims)

# %%
import time
start = time.time()
numSims = 100
for i in range(numSims):
    #rr.load(sbml)
    rr.reset()
    rr.simulate(0, 100, 100)
end = time.time()
print '%s seconds' % str(end-start)
print '%s seconds/sim' % str((end-start)/numSims)

# %%
import tasks
from celery import group

@app.task
def error_handler(uuid):
    result = AsyncResult(uuid)
    exc = result.get(propagate=False)
    print('Task {0} raised exception: {1!r}\n{2!r}'.format(
          uuid, exc, result.traceback))

def 

result = group([tasks.rrRun.s('getnfo'), link]).apply_async()
result.get()

# %%
import celery

# %%
print celery.VERSION
